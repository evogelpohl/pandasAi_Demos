# %% [markdown]
# <img src='https://data.cityofchicago.org/api/assets/73F1665C-0FE6-4183-8AD1-E91DB8EFAFA4?7CB02402-8E06-48B0-8C9A-3890182D58C7.png'>

# %%
import pandas as pd
crime = pd.read_csv('https://raw.githubusercontent.com/evogelpohl/pandasAI_project/main/chicago_iucr.csv')

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# Assuming df is your DataFrame
# You can replace df with the name of your DataFrame variable

# Concatenating 'primary_type' and 'description' into a new column 'crime'
crime['crime'] = crime['primary_type'] + ' - ' + crime['description']

# Display the first few rows to verify
#print(crime[['primary_type', 'description', 'crime']].head())

# %%
df_head = crime.head(3)

# %%
field_descriptions = {
    "id": "The Socrata DB ID",
    "arrest": "Indicates whether an arrest was made.",
    "beat": "Police beat where the incident occurred, part of the smallest police geographic area.",
    "block": "Partially redacted address where the incident occurred, within the same block as the actual address.",
    "case_number": "Unique RD Number (Records Division Number) assigned by the Chicago Police Department.",
    "datetime": "The Date and Time when the incident occurred, sometimes an estimate.",
    "date": "The Date when the incent occurred. Date only for groupby.",
    "description": "Secondary description of the IUCR code, a subcategory of the primary description.",
    "location_description": "Description of the location where the incident occurred.",
    "primary_iucr_desc": "The primary description of the IUCR, or Illinois Uniform Crime Report",
    "secondary_iucr_desc": "The secondary description of the IUCR, or Illinois Uniform Crime Report",
    "district": "Police district where the incident occurred.",
    "domestic": "Indicates whether the incident was domestic-related as per the Illinois Domestic Violence Act.",
    "fbi_code": "Crime classification as outlined in the FBI's National Incident-Based Reporting System (NIBRS).",
    "iucr": "Illinois Uniform Crime Reporting code linked to the primary and secondary descriptions.",
    "id": "Unique identifier for the record.",
    "latitude": "Latitude of the incident location, shifted for partial redaction but on the same block.",
    "location": "Location where the incident occurred in a JSON format for mapping and geographic operations.",
    "longitude": "Longitude of the incident location, shifted for partial redaction but on the same block.",
    "updated_on": "Date and time the record was last updated.",
    "ward": "City Council district (ward) where the incident occurred.",
    "year": "Year the incident occurred.",
    "community_area": "Indicates the community area where the incident occurred, with Chicago having 77 community areas.",
    "crime": "The full crime name which is the primary and secondary item concatenated."
}

# %%
# Retrieve the API key from environment variables


import os
from pandasai import SmartDataframe
from pandasai.llm import AzureOpenAI
from pandasai.llm.local_llm import LocalLLM
from pandasai.llm import OpenAI
from pandasai import Agent
from pandasai.llm.openai import OpenAI
from pandasai.connectors import PandasConnector
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

# Get my Openai Var Key
open_ai_key = os.getenv('OPENAI_API_KEY')

# Choose the model
select_model = 'Azure' #OpenAI $$, #AzureOpenAI #Presdio #Local MyModel mY Macbook

if select_model == 'Azure':
    # Define the LLM model for Azure (if True)
    azure_api_key = os.getenv('AZURE_OPENAI_API_KEY')
    azure_api_ver = os.getenv('AZURE_API_VERSION')
    azure_api_endpt = os.getenv('AZURE_OPENAI_ENDPOINT')
    azure_oai_deployment = os.getenv('AZURE_OPENAI_DEPLOYMENT')
    llm = AzureOpenAI(
        api_token=azure_api_key,
        azure_endpoint=azure_api_endpt,
        api_version=azure_api_ver,
        deployment_name=azure_oai_deployment,
        temperature=0,
        seed=26,
    )
elif select_model == 'OpenAI':
    openai_api_key = os.getenv('OPENAI_API_KEY')
    llm = OpenAI(api_token=openai_api_key, 
                 temperature=0,
                 seed=35,
                )
    
elif select_model == 'Local':
    llm = LocalLLM(api_base="http://host.docker.internal:1234/v1",
                  temperature=0, 
                  seed=55,
                  )


# A description of the overall table
description = '''You are a data analysis agent. Your main goal is to help non-technical users to analyze data.\
                Act as a data analyst. Every time I ask you a question, you should provide the code to visualize \
                the answer using plotly. \
                This dataset reflects reported incidents of crime (with the exception of murders where \
                data exists for each victim) that occurred in the City of Chicago from 2001 to present, \
                minus the most recent seven days. Data is extracted from the Chicago Police Department's \
                CLEAR (Citizen Law Enforcement Analysis and Reporting) system. In order to protect the privacy of crime victims, \
                addresses are shown at the block level only and specific locations are not identified. '''

# Define my connector
agent = Agent(crime, config={'llm': llm,
                            'description': description,
                            'enable_cache': False,
                            'verbose': False,
                            'field_description': field_descriptions,
                            'save_charts': True,
                            'save_charts_path': './saved_plots',
                            }
             )

# %%
query = ''' Plot and show as a bar chart: Where are the top 10 location_descriptions (remove null and blank or ' ' space \
                from the chart) for the primary_type of 'THEFT' crime committed in the year 2024? Use modern color theme and \
                include in-line comments in your code please. '''
agent.chat(query)
# Out:
# 2024-03-21 00:44:04 [INFO] Question:  Plot and show as a bar chart: Where are the top 10 location_descriptions (remove null and blank or ' ' space                 from the chart) for the primary_type of 'THEFT' crime committed in the year 2024? Use modern color theme and                 include in-line comments in your code please.
# 2024-03-21 00:44:04 [INFO] Running PandasAI with azure-openai LLM...
# 2024-03-21 00:44:04 [INFO] Prompt ID: ef94dc42-1cc4-4145-a755-4e58ab976a50
# 2024-03-21 00:44:04 [INFO] Executing Pipeline: GenerateChatPipeline
# 2024-03-21 00:44:04 [INFO] Executing Step 0: ValidatePipelineInput
# 2024-03-21 00:44:04 [INFO] Executing Step 1: CacheLookup
# 2024-03-21 00:44:05 [INFO] Executing Step 2: PromptGeneration
# 2024-03-21 00:44:05 [INFO] Using prompt: dfs[0]:
#   name: null
#   description: null
#   type: pd.DataFrame
#   rows: 50000
#   columns: 20
#   schema:
#     fields:
#     - name: id
#       type: int64
#       samples:
#       - 13338522
#       - 13321748
#       - 13340680
#     - name: case_number
#       type: object
#       samples:
#       - JH169195
#       - JH169677
#       - JG555038
#     - name: datetime
#       type: object
#       samples:
#       - '2024-02-01 15:20:00'
#       - '2024-02-22 03:10:00'
#       - '2024-01-31 10:48:00'
#     - name: block
#       type: object
#       samples:
#       - 055XX S KOLMAR AVE
#       - 047XX S AVERS AVE
#       - 006XX N Michigan AVE
#     - name: primary_type
#       type: object
#       samples:
#       - CRIMINAL DAMAGE
#       - OBSCENITY
#       - BATTERY
#     - name: description
#       type: object
#       samples:
#       - AGGRAVATED POLICE OFFICER - OTHER FIREARM
#       - CRIMINAL SEXUAL ABUSE
#       - UNAUTHORIZED VIDEOTAPING
#     - name: location_description
#       type: object
#       samples:
#       - .nan
#       - GOVERNMENT BUILDING / PROPERTY
#       - GROCERY FOOD STORE
#     - name: arrest
#       type: bool
#       samples:
#       - true
#       - false
#       - true
#     - name: domestic
#       type: bool
#       samples:
#       - true
#       - false
#       - true
#     - name: beat
#       type: int64
#       samples:
#       - 1225
#       - 233
#       - 924
#     - name: district
#       type: int64
#       samples:
#       - 4
#       - 20
#       - 18
#     - name: ward
#       type: int64
#       samples:
#       - 37
#       - 39
#       - 12
#     - name: community_area
#       type: float64
#       samples:
#       - 2.0
#       - 23.0
#       - .nan
#     - name: fbi_code
#       type: object
#       samples:
#       - '24'
#       - '05'
#       - '14'
#     - name: year
#       type: int64
#       samples:
#       - 2023
#       - 2023
#       - 2024
#     - name: latitude
#       type: float64
#       samples:
#       - 41.799520608
#       - .nan
#       - 41.771582376
#     - name: longitude
#       type: float64
#       samples:
#       - .nan
#       - -87.667856126
#       - -87.665647616
#     - name: location
#       type: object
#       samples:
#       - .nan
#       - '{''latitude'': ''41.928822325'', ''longitude'': ''-87.687781609'', ''human_address'':
#         ''{"address": "", "city": "", "state": "", "zip": ""}''}'
#       - '{''latitude'': ''41.87963019'', ''longitude'': ''-87.736682152'', ''human_address'':
#         ''{"address": "", "city": "", "state": "", "zip": ""}''}'
#     - name: date
#       type: object
#       samples:
#       - '2024-01-25'
#       - '2024-01-19'
#       - '2024-02-21'
#     - name: crime
#       type: object
#       samples:
#       - WEAPONS VIOLATION - UNLAWFUL POSSESSION - OTHER FIREARM
#       - BATTERY - AGGRAVATED OF A SENIOR CITIZEN
#       - CONCEALED CARRY LICENSE VIOLATION - PROHIBITED PLACES
#
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#   Plot and show as a bar chart: Where are the top 10 location_descriptions (remove null and blank or ' ' space                 from the chart) for the primary_type of 'THEFT' crime committed in the year 2024? Use modern color theme and                 include in-line comments in your code please.
#
# Variable `dfs: list[pd.DataFrame]` is already declared.
#
# At the end, declare "result" variable as a dictionary of type and value.
#
# If you are asked to plot a chart, use "matplotlib" for charts, save as png.
#
#
# Generate python code and return full updated code:
# 2024-03-21 00:44:05 [INFO] Executing Step 3: CodeGenerator
# 2024-03-21 00:44:41 [INFO] HTTP Request: POST https://oai-evogelpohl-01.openai.azure.com//openai/deployments/evogelpohl-gpt4-2/chat/completions?api-version=2024-02-15-preview "HTTP/1.1 200 OK"
# 2024-03-21 00:44:41 [INFO] Prompt used:
#             dfs[0]:
#   name: null
#   description: null
#   type: pd.DataFrame
#   rows: 50000
#   columns: 20
#   schema:
#     fields:
#     - name: id
#       type: int64
#       samples:
#       - 13338522
#       - 13321748
#       - 13340680
#     - name: case_number
#       type: object
#       samples:
#       - JH169195
#       - JH169677
#       - JG555038
#     - name: datetime
#       type: object
#       samples:
#       - '2024-02-01 15:20:00'
#       - '2024-02-22 03:10:00'
#       - '2024-01-31 10:48:00'
#     - name: block
#       type: object
#       samples:
#       - 055XX S KOLMAR AVE
#       - 047XX S AVERS AVE
#       - 006XX N Michigan AVE
#     - name: primary_type
#       type: object
#       samples:
#       - CRIMINAL DAMAGE
#       - OBSCENITY
#       - BATTERY
#     - name: description
#       type: object
#       samples:
#       - AGGRAVATED POLICE OFFICER - OTHER FIREARM
#       - CRIMINAL SEXUAL ABUSE
#       - UNAUTHORIZED VIDEOTAPING
#     - name: location_description
#       type: object
#       samples:
#       - .nan
#       - GOVERNMENT BUILDING / PROPERTY
#       - GROCERY FOOD STORE
#     - name: arrest
#       type: bool
#       samples:
#       - true
#       - false
#       - true
#     - name: domestic
#       type: bool
#       samples:
#       - true
#       - false
#       - true
#     - name: beat
#       type: int64
#       samples:
#       - 1225
#       - 233
#       - 924
#     - name: district
#       type: int64
#       samples:
#       - 4
#       - 20
#       - 18
#     - name: ward
#       type: int64
#       samples:
#       - 37
#       - 39
#       - 12
#     - name: community_area
#       type: float64
#       samples:
#       - 2.0
#       - 23.0
#       - .nan
#     - name: fbi_code
#       type: object
#       samples:
#       - '24'
#       - '05'
#       - '14'
#     - name: year
#       type: int64
#       samples:
#       - 2023
#       - 2023
#       - 2024
#     - name: latitude
#       type: float64
#       samples:
#       - 41.799520608
#       - .nan
#       - 41.771582376
#     - name: longitude
#       type: float64
#       samples:
#       - .nan
#       - -87.667856126
#       - -87.665647616
#     - name: location
#       type: object
#       samples:
#       - .nan
#       - '{''latitude'': ''41.928822325'', ''longitude'': ''-87.687781609'', ''human_address'':
#         ''{"address": "", "city": "", "state": "", "zip": ""}''}'
#       - '{''latitude'': ''41.87963019'', ''longitude'': ''-87.736682152'', ''human_address'':
#         ''{"address": "", "city": "", "state": "", "zip": ""}''}'
#     - name: date
#       type: object
#       samples:
#       - '2024-01-25'
#       - '2024-01-19'
#       - '2024-02-21'
#     - name: crime
#       type: object
#       samples:
#       - WEAPONS VIOLATION - UNLAWFUL POSSESSION - OTHER FIREARM
#       - BATTERY - AGGRAVATED OF A SENIOR CITIZEN
#       - CONCEALED CARRY LICENSE VIOLATION - PROHIBITED PLACES
#
#
#
#
# Update this initial code:
# ```python
# # TODO: import the required dependencies
# import pandas as pd
#
# # Write code here
#
# # Declare result var:
# type (possible values "string", "number", "dataframe", "plot"). Examples: { "type": "string", "value": f"The highest salary is {highest_salary}." } or { "type": "number", "value": 125 } or { "type": "dataframe", "value": pd.DataFrame({...}) } or { "type": "plot", "value": "temp_chart.png" }
#
# ```
#
#
#
# ### QUERY
#   Plot and show as a bar chart: Where are the top 10 location_descriptions (remove null and blank or ' ' space                 from the chart) for the primary_type of 'THEFT' crime committed in the year 2024? Use modern color theme and                 include in-line comments in your code please.
#
# Variable `dfs: list[pd.DataFrame]` is already declared.
#
# At the end, declare "result" variable as a dictionary of type and value.
#
# If you are asked to plot a chart, use "matplotlib" for charts, save as png.
#
#
# Generate python code and return full updated code:
#
# 2024-03-21 00:44:41 [INFO] Code generated:
#             ```
#             # Import the required dependencies
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Assuming dfs is a list of DataFrames and we are interested in the first one
# df = dfs[0]
#
# # Filter the DataFrame for the year 2024 and primary_type 'THEFT'
# theft_df_2024 = df[(df['year'] == 2024) & (df['primary_type'] == 'THEFT')]
#
# # Remove rows where location_description is null, blank or just spaces
# theft_df_2024 = theft_df_2024[theft_df_2024['location_description'].notna() & theft_df_2024['location_description'].str.strip().astype(bool)]
#
# # Count occurrences of each location_description and get the top 10
# top_10_locations = theft_df_2024['location_description'].value_counts().head(10)
#
# # Plotting
# plt.figure(figsize=(10, 6))
# top_10_locations.plot(kind='bar', color='skyblue')
# plt.title('Top 10 Locations for Theft Crimes in 2024')
# plt.xlabel('Location Description')
# plt.ylabel('Number of Incidents')
# plt.xticks(rotation=45, ha='right')
#
# # Save the plot as a PNG file
# plt.savefig('top_10_theft_locations_2024.png')
#
# # Declare result var with the path to the saved plot
# result = { "type": "plot", "value": "top_10_theft_locations_2024.png" }
#             ```
#
# 2024-03-21 00:44:41 [INFO] Executing Step 4: CachePopulation
# 2024-03-21 00:44:41 [INFO] Executing Step 5: CodeExecution
# 2024-03-21 00:44:41 [INFO] Saving charts to saved_plots/ef94dc42-1cc4-4145-a755-4e58ab976a50.png
# 2024-03-21 00:44:41 [INFO]
# Code running:
# ```
# df = dfs[0]
# theft_df_2024 = df[(df['year'] == 2024) & (df['primary_type'] == 'THEFT')]
# theft_df_2024 = theft_df_2024[theft_df_2024['location_description'].notna() & theft_df_2024['location_description'].str.strip().astype(bool)]
# top_10_locations = theft_df_2024['location_description'].value_counts().head(10)
# plt.figure(figsize=(10, 6))
# top_10_locations.plot(kind='bar', color='skyblue')
# plt.title('Top 10 Locations for Theft Crimes in 2024')
# plt.xlabel('Location Description')
# plt.ylabel('Number of Incidents')
# plt.xticks(rotation=45, ha='right')
# plt.savefig('saved_plots/ef94dc42-1cc4-4145-a755-4e58ab976a50.png')
# result = {'type': 'plot', 'value': 'saved_plots/ef94dc42-1cc4-4145-a755-4e58ab976a50.png'}
#         ```
# 2024-03-21 00:44:42 [INFO] Executing Step 6: ResultValidation
# 2024-03-21 00:44:42 [INFO] Answer: {'type': 'plot', 'value': 'saved_plots/ef94dc42-1cc4-4145-a755-4e58ab976a50.png'}
# 2024-03-21 00:44:42 [INFO] Executing Step 7: ResultParsing
# 'saved_plots/ef94dc42-1cc4-4145-a755-4e58ab976a50.png'

# %%
print(agent.last_code_generated)
# Out:
# # Import the required dependencies
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Assuming dfs is a list of DataFrames and we are interested in the first one
# df = dfs[0]
#
# # Filter the DataFrame for the year 2024 and primary_type 'THEFT'
# theft_df_2024 = df[(df['year'] == 2024) & (df['primary_type'] == 'THEFT')]
#
# # Remove rows where location_description is null, blank or just spaces
# theft_df_2024 = theft_df_2024[theft_df_2024['location_description'].notna() & theft_df_2024['location_description'].str.strip().astype(bool)]
#
# # Count occurrences of each location_description and get the top 10
# top_10_locations = theft_df_2024['location_description'].value_counts().head(10)
#
# # Plotting
# plt.figure(figsize=(10, 6))
# top_10_locations.plot(kind='bar', color='skyblue')
# plt.title('Top 10 Locations for Theft Crimes in 2024')
# plt.xlabel('Location Description')
# plt.ylabel('Number of Incidents')
# plt.xticks(rotation=45, ha='right')
#
# # Save the plot as a PNG file
# plt.savefig('top_10_theft_locations_2024.png')
#
# # Declare result var with the path to the saved plot
# result = { "type": "plot", "value": "top_10_theft_locations_2024.png" }

# %%
agent.explain()
# Out:
# 2024-03-21 00:44:42 [INFO] HTTP Request: POST https://oai-evogelpohl-01.openai.azure.com//openai/deployments/evogelpohl-gpt4-2/chat/completions?api-version=2024-02-15-preview "HTTP/1.1 429 Too Many Requests"
# 2024-03-21 00:44:42 [INFO] Retrying request to /chat/completions in 23.000000 seconds
# 2024-03-21 00:45:40 [INFO] HTTP Request: POST https://oai-evogelpohl-01.openai.azure.com//openai/deployments/evogelpohl-gpt4-2/chat/completions?api-version=2024-02-15-preview "HTTP/1.1 200 OK"
# 2024-03-21 00:45:40 [INFO] Explanation:  Sure, let's break down the process into simple steps, avoiding technical jargon:
#
# 1. **Gathering Data**: Imagine we have a large book that records every instance of theft in the year 2024. Each entry in this book includes where the theft happened, among other details.
#
# 2. **Focusing on Theft**: Since we're only interested in thefts, we first go through our big book and take out all the pages that talk about theft. This leaves us with a smaller, more focused collection of information.
#
# 3. **Cleaning Up**: Some of the entries might not tell us where the theft happened—they might be blank or just not filled in. We remove those because they don't help us answer our question about locations.
#
# 4. **Finding Popular Spots**: With our cleaned-up information, we then count how many thefts happened at each location. This helps us identify the top 10 spots where thefts are most common.
#
# 5. **Creating a Chart**: To make our findings easy to understand, we decide to draw a bar chart. Each bar represents one of the top 10 locations, and the height of the bar shows how many thefts occurred there. We choose pleasant colors and arrange everything neatly so it's easy to read.
#
# 6. **Sharing Our Findings**: Finally, we save this chart as an image. This way, we can easily share it with others who are interested in knowing about the most common places for thefts in 2024, without them having to go through all the data themselves.
#
# In essence, we took a large set of information about thefts, focused on what's important for our question, cleaned up any incomplete data, identified the most common locations for thefts, and then visualized this information in a simple and accessible way.
# "Sure, let's break down the process into simple steps, avoiding technical jargon:\n\n1. **Gathering Data**: Imagine we have a large book that records every instance of theft in the year 2024. Each entry in this book includes where the theft happened, among other details.\n\n2. **Focusing on Theft**: Since we're only interested in thefts, we first go through our big book and take out all the pages that talk about theft. This leaves us with a smaller, more focused collection of information.\n\n3. **Cleaning Up**: Some of the entries might not tell us where the theft happened—they might be blank or just not filled in. We remove those because they don't help us answer our question about locations.\n\n4. **Finding Popular Spots**: With our cleaned-up information, we then count how many thefts happened at each location. This helps us identify the top 10 spots where thefts are most common.\n\n5. **Creating a Chart**: To make our findings easy to understand, we decide to draw a bar chart. Each bar represents one of the top 10 locations, and the height of the bar shows how many thefts occurred there. We choose pleasant colors and arrange everything neatly so it's easy to read.\n\n6. **Sharing Our Findings**: Finally, we save this chart as an image. This way, we can easily share it with others who are interested in knowing about the most common places for thefts in 2024, without them having to go through all the data themselves.\n\nIn essence, we took a large set of information about thefts, focused on what's important for our question, cleaned up any incomplete data, identified the most common locations for thefts, and then visualized this information in a simple and accessible way."
